# %% [markdown]
# # 1. 패키지 임포트

# %%
import numpy as np
import pandas as pd
import folium
import pandas_profiling
import matplotlib as mpl
import matplotlib.pyplot as plt
import missingno as msno
import seaborn as sns
# %matplotlib inline
from tqdm import tqdm
import datetime
import json
import matplotlib_inline.backend_inline
matplotlib_inline.backend_inline.set_matplotlib_formats('retina')

mpl.rc('font', family='binggrae')
mpl.rc('axes', unicode_minus=True)
pd.options.display.max_columns = 100
pd.options.display.max_rows = 10000

# %% [markdown]
# # 2. 데이터 로드

# %%
df = pd.read_csv('../data/project2/smartcard_Chain.csv', encoding='cp949')

# %%
# 데이터 shape 파악
print(df.shape)
# Out:
# (8206179, 23)

# %%
# 데이터 결측치 확인
df.isnull().sum()
# Out:
# card_name               0
# Bus                     0
# Subway                  0
# on_area_name            0
# on_lon                  0
# on_lat                  0
# on_dong                 0
# on_hour                 0
# on_minute               0
# on_second               0
# off_area_name           0
# off_lon                 0
# off_lat                 0
# off_dong                0
# off_hour                0
# off_minute              0
# off_second              0
# no_transfer             0
# total_distance          0
# total_time              0
# route_id          3398018
# Haversine               0
# Circuity            72738
# dtype: int64

# %%
# 데이터 결측치 시각화
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 3. 데이터 정제
# - df : 원본데이터
# - df_copy = df.copy()

# %% [markdown]
# - card_name이 같은 사람은 환승을 했을 것이다.

# %%
df_copy = df.copy()

# %%
df_copy.head(3)
# Out:
#                                       card_name    Bus  Subway on_area_name  \
# 0  +++0VxU0B9DrLE4nxWaOzEArKFNI3ep9kMPVTZVHGNM=  False    True       영등포시장역
# 1  +++0VxU0B9DrLE4nxWaOzEArKFNI3ep9kMPVTZVHGNM=  False    True         충무로역
# 2  +++0VxU0B9DrLE4nxWaOzEArKFNI3ep9kMPVTZVHGNM=  False    True          중곡역
#
#        on_lon     on_lat  on_dong  on_hour  on_minute  on_second  \
# 0  126.905118  37.522694  1119074       12         42          8
# 1  126.993624  37.561135  1102060       16          2          9
# 2  127.084283  37.565891  1105057       18         22         39
#
#   off_area_name     off_lon    off_lat  off_dong  off_hour  off_minute  \
# 0          충무로역  126.993624  37.561135   1102060        13          16
# 1           중곡역  127.084283  37.565891   1105057        16          36
# 2          선유도역  126.893294  37.538159   1119062        19          19
#
#    off_second  no_transfer  total_distance  total_time  route_id  \
# ...

# %%
df_copy[['total_

# %%
df_copy['total_distance'].dtype
# Out:
# dtype('int64')

# %%
df_copy['Circuity'] = np.where(df_copy['Circuity'] == 0.0, np.NaN, df_copy['Circuity'])
df_copy['Circuity'] = np.where(df_copy['Haversine'] == 0, np.NaN, df_copy['Circuity'])

# %%
print(df[df['total_distance']==0].shape)
print(df[df['Haversine']==0].shape)
# Out:
# (111837, 23)
# (74933, 23)

# %%
df_copy.isnull().sum()
# Out:
# card_name               0
# Bus                     0
# Subway                  0
# on_area_name            0
# on_lon                  0
# on_lat                  0
# on_dong                 0
# on_hour                 0
# on_minute               0
# on_second               0
# off_area_name           0
# off_lon                 0
# off_lat                 0
# off_dong                0
# off_hour                0
# off_minute              0
# off_second              0
# no_transfer             0
# total_distance          0
# total_time              0
# route_id          3398018
# Haversine               0
# Circuity           114032
# dtype: int64

# %%
df_copy['total_distance'] = np.where(df_copy['total_distance'] == 0, np.NaN, df_copy['total_distance'])
df_copy['Haversine'] = np.

# %%
2052/

# %%
df.head(10)
# Out:
#                                       card_name    Bus  Subway on_area_name  \
# 0  +++0VxU0B9DrLE4nxWaOzEArKFNI3ep9kMPVTZVHGNM=  False    True       영등포시장역
# 1  +++0VxU0B9DrLE4nxWaOzEArKFNI3ep9kMPVTZVHGNM=  False    True         충무로역
# 2  +++0VxU0B9DrLE4nxWaOzEArKFNI3ep9kMPVTZVHGNM=  False    True          중곡역
# 3  +++19/4InCnN/eZXlK0pT7oFlp3qEbVXHX4NFSiyAN8=   True   False     LG전자.문래중
# 4  +++3lFnkOIxAPXhin+oeJBZJeI8l5KOhgxcjhFqGTlc=   True   False   강남구청.강남세무서
# 5  +++F6kFULTd2oQ7KiAe3olIQ0mzelgLbSx+q6rqtJqA=   True   False       중동초등학교
# 6  +++F6kFULTd2oQ7KiAe3olIQ0mzelgLbSx+q6rqtJqA=   True   False        홍대입구역
# 7  +++Mu6n16tNt3pAX8k72E1UlIZXRqojexmEcPIaArto=  False    True         압구정역
# 8  +++Mu6n16tNt3pAX8k72E1UlIZXRqojexmEcPIaArto=  False    True       을지로3가역
# 9  +++PAYzWTdRTGJKcBiZ1g/w9Ik/WgyDTTve7H410Tbo=  False    True          창동역
#
#        on_lon     on_lat  on_dong  on_hour  on_minute  on_second  \
# 0  126.905118  37.522694  1119074       12         42          8
# ...

# %%
df['on_time'] = df['on_hour'].astype(str)+':'+df['on_minute'].astype(str)+':'+df['on_second'].astype(str)
df.head()
# Out:
#                                       card_name    Bus  Subway on_area_name  \
# 0  +++0VxU0B9DrLE4nxWaOzEArKFNI3ep9kMPVTZVHGNM=  False    True       영등포시장역
# 1  +++0VxU0B9DrLE4nxWaOzEArKFNI3ep9kMPVTZVHGNM=  False    True         충무로역
# 2  +++0VxU0B9DrLE4nxWaOzEArKFNI3ep9kMPVTZVHGNM=  False    True          중곡역
# 3  +++19/4InCnN/eZXlK0pT7oFlp3qEbVXHX4NFSiyAN8=   True   False     LG전자.문래중
# 4  +++3lFnkOIxAPXhin+oeJBZJeI8l5KOhgxcjhFqGTlc=   True   False   강남구청.강남세무서
#
#        on_lon     on_lat  on_dong  on_hour  on_minute  on_second  \
# 0  126.905118  37.522694  1119074       12         42          8
# 1  126.993624  37.561135  1102060       16          2          9
# 2  127.084283  37.565891  1105057       18         22         39
# 3  126.885883  37.520390  1119076       16         11         56
# 4  127.047293  37.518428  1123078       18          4         57
#
#   off_area_name     off_lon    off_lat  off_dong  off_hour  off_minute  \
# ...

# %%
df['on_time'].to_datetime()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15140/3239194705.py in <module>
# ----> 1 df['on_time'].to_datetime()
#
# ~\anaconda3\envs\py38\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'to_datetime'

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2021, 12, 22, 16, 58, 40, 287274)

# %%
ex1 = df[['on_area_name', 'off_area_name', 'total_distance', 'Haversine']]

# %%
ex1.head(10)
# Out:
#   on_area_name   off_area_name  total_distance     Haversine
# 0       영등포시장역            충무로역           11000   8897.367673
# 1         충무로역             중곡역            9400   8008.336598
# 2          중곡역            선유도역           20100  17116.783674
# 3     LG전자.문래중             문래역             768    766.539891
# 4   강남구청.강남세무서       청담동래미안아파트             397    395.878621
# 5       중동초등학교  연희104고지앞.구성산회관            1457   1302.056387
# 6        홍대입구역            성산2교            1432   1193.729520
# 7         압구정역             회현역            6700   5685.353574
# 8       을지로3가역            압구정역            6000   5452.191576
# 9          창동역          미아사거리역            5700   4704.914692

# %%
ex2 = df[['on_lon', 'on_lat', 'off_lon', 'off_lat']]
ex2.head(5)
ex3 = ex2.iloc[0:101]

# %%
location_tpe = [(i,v) for i,v in tqdm(ex2.iloc[:, 1:3].values)]
location_tpe[0:3]
# Out:
# 100%|██████████| 8206179/8206179 [00:07<00:00, 1170195.86it/s]
# [(37.522694, 126.993624), (37.561135, 127.084283), (37.565891, 126.893294)]

# %%
location_tpe = location_tpe[0:100]

# %%
geo_data = json.load(open('../data/project2/skorea_municipalities_geo_simple.json', encoding='utf-8'))

# %%
center = [37.541, 126.986]
m1 = folium.Map(location=center, zoom_start=10.5)
folium.Choropleth(
        geo_data=geo_data,
        data=ex3,
        columns=('on_lon', 'on_lat'),
        key_on='feature.properties.name',
        fill_color='Reds',
        fill_opacity=0.8).add_to(m1)
m1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
m = folium.Map(location=location_tpe)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15140/2642106766.py in <module>
# ----> 1 m = folium.Map(location=location_tpe)
#
# ~\anaconda3\envs\py38\lib\site-packages\folium\folium.py in __init__(self, location, width, height, left, top, position, tiles, attr, min_zoom, max_zoom, zoom_start, min_lat, max_lat, min_lon, max_lon, max_bounds, crs, control_scale, prefer_canvas, no_touch, disable_3d, png_enabled, zoom_control, **kwargs)
#     253             zoom_start = 1
#     254         else:
# --> 255             self.location = validate_location(location)
#     256
#     257         Figure().add_child(self)
#
# ~\anaconda3\envs\py38\lib\site-packages\folium\utilities.py in validate_location(location)
#      48                         '{!r} of type {}.'.format(location, type(location)))
#      49     if len(location) != 2:
# ...

# %%
plt.figure(figsize=(10,15))
sns.scatterplot(x=ex2['on_lon'], y=ex2['on_lat'])
sns.scatterplot(x=ex2['off_lon'], y=ex2['off_lat'])
# Out:
# <AxesSubplot:xlabel='on_lon', ylabel='on_lat'>
